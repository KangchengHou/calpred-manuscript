# %%
import numpy as np
import pandas as pd

# %%
df_cov = pd.read_csv("../../compile-data/out/covar.tsv", sep='\t', index_col=0)

# %%
df_cov[df_cov['group'] != "United Kingdom"]
# Out:
#          AGE  SEX  DEPRIVATION_INDEX        PC1        PC2        PC3  \
# INDIV
# 5501069   60    0          -0.982022  -12.43740    2.76059  -0.248736
# 3008039   43    1          -1.102330  -14.36620    2.62983  -3.526230
# 4799507   43    1           1.489100   -7.88334   -2.96238  -0.827765
# 1779792   57    0          -2.644990  -11.53820    2.35427  -0.592917
# 2678693   60    0          -1.307780  -13.69880    1.73149  -2.755210
# ...      ...  ...                ...        ...        ...        ...
# 5470366   60    1           0.905939  200.36700  -81.58280 -16.867000
# 3135174   46    0           1.255520  -13.97340    3.41305  -1.719330
# 3928276   51    0           0.222304  -11.74780    3.17302  -1.217540
# 4031831   51    0          -1.612000  -14.07350    2.46635  -1.064270
# 5738092   45    0          -4.105290   64.82530 -118.29300 -44.576000
#
#               PC4      PC5        PC6        PC7  ...       PC9       PC10  \
# ...
